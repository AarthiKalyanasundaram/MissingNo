# %%
import pandas as pd
import numpy as np
import seaborn as sns 
from matplotlib import pyplot as plt
import missingno as msno

# %%
PP = pd.read_csv("D:/Train/Patient_Profile.csv")

# %%
PP.head()
# Out:
#    Patient_ID  Online_Follower  LinkedIn_Shared  Twitter_Shared  \
# 0      516956                0                0               0
# 1      507733                0                0               0
# 2      508307                0                0               0
# 3      512612                0                0               0
# 4      521075                0                0               0
#
#    Facebook_Shared Income Education_Score Age First_Interaction City_Type  \
# 0                0      1              90  39         18-Jun-03       NaN
# 1                0      1            None  40         20-Jul-03         H
# 2                0      3              87  46         02-Nov-02         D
# 3                0      1              75  47         02-Nov-02         D
# 4                0      3            None  80         24-Nov-02         H
#
#    Employer_Category
# 0  Software Industry
# 1  Software Industry
# 2               BFSI
# 3          Education
# 4             Others

# %%
PP["Online_Score"] = PP["Online_Follower"] + PP["LinkedIn_Shared"] + PP["Twitter_Shared"] + PP["Facebook_Shared"]

# %%
del PP["Online_Follower"]
del PP["LinkedIn_Shared"]
del PP["Twitter_Shared"]
del PP["Facebook_Shared"]

# %%
PP.head(20)
# Out:
#     Patient_ID Income Education_Score   Age First_Interaction City_Type  \
# 0       516956      1              90    39         18-Jun-03       NaN
# 1       507733      1            None    40         20-Jul-03         H
# 2       508307      3              87    46         02-Nov-02         D
# 3       512612      1              75    47         02-Nov-02         D
# 4       521075      3            None    80         24-Nov-02         H
# 5       502103   None            None  None         06-Apr-03       NaN
# 6       528501   None            None  None         26-Apr-03       NaN
# 7       519202   None            None  None         05-Apr-03       NaN
# 8       521359   None            None  None         10-Apr-03         F
# 9       487977      4              72    58         08-Jun-03         G
# 10      518680      0            None    48         31-May-03         B
# 11      497120      1              75    42         12-Apr-03         B
# 12      528043   None     73.85333333    52         06-Jul-03         B
# 13      510954   None            None  None         04-Jul-03         G
# 14      509188      1              67    56         06-Mar-03         F
# 15      511565   None            None  None         07-Jul-03       NaN
# 16      495861   None            None  None         06-Jul-03       NaN
# 17      518080      0            None    49         12-Jul-03         F
# 18      488558      0            None    38         09-Nov-02         G
# 19      514739   None            None  None         08-Jul-03         E
#
#     Employer_Category  Online_Score
# 0   Software Industry             0
# 1   Software Industry             0
# 2                BFSI             0
# 3           Education             0
# 4              Others             0
# 5                 NaN             0
# 6                 NaN             0
# 7                 NaN             0
# 8                 NaN             0
# 9          Technology             2
# 10                NaN             1
# 11          Education             2
# 12         Consulting             0
# 13                NaN             0
# 14         Technology             0
# 15                NaN             0
# 16                NaN             0
# 17         Consulting             0
# 18                NaN             3
# 19                NaN             0

# %%
PP.replace("None", np.NaN, inplace = True)

# %% [markdown]
# ## Visualization of Missing data
# For doing that, we have to import missingno as msno

# %%
import missingno as msno
msno.bar(PP)
plt.show()
